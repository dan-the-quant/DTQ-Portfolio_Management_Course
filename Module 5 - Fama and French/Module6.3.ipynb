# %% [markdown]
# # Fama and French Factor Model #

# %% [markdown]
# ### The Model Specification ###

# %%
# Import Libraries

# Data Management
import pandas as pd
import numpy as np

# Plots
import matplotlib.pyplot as plt

# Statistics
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import norm

# Handle Files
import sys
import os

# Import Local Functions
sys.path.append(os.path.abspath("../source"))
from functions import import_financial_data
from functions import import_stock_universe
from capm_toolkit import wexp
from capm_toolkit import compute_daily_returns
from capm_toolkit import compute_excess_returns
from capm_toolkit import capm_regression

# %%
# Get Data from Stock

ticker = 'MSFT'

stock_price = import_financial_data(ticker)
stock_returns = stock_price['adj_close'].pct_change(1).dropna()

stock_returns
# Out:
# Date
# 2015-01-05   -0.009303
# 2015-01-06   -0.014571
# 2015-01-07    0.012705
# 2015-01-08    0.029418
# 2015-01-09   -0.008405
#                 ...
# 2024-10-22    0.020846
# 2024-10-23   -0.006807
# 2024-10-24    0.000306
# 2024-10-25    0.008052
# 2024-10-28   -0.003644
# Name: adj_close, Length: 2471, dtype: float64

# %%
# Get the important data for the Risk Free Rate
rfr = pd.read_csv(r"..\additional_data\rfr.csv")
rfr = rfr.set_index('Date')
rfr.index = pd.to_datetime(rfr.index, dayfirst=True)

# Get the important data for the S&P500
sp500 = pd.read_csv(r"..\additional_data\sp500.csv")
sp500 = sp500.set_index('Date')
sp500.index = pd.to_datetime(sp500.index)

# Get the data for the SMB Premium
SMB = pd.read_csv(r"..\additional_data\famafrench_smb.csv")
SMB = SMB.set_index('Date')
SMB.index = pd.to_datetime(SMB.index)

# Get the data for the HML Premium
HML = pd.read_csv(r"..\additional_data\famafrench_hml.csv")
HML = HML.set_index('Date')
HML.index = pd.to_datetime(HML.index)

# %%
# Create the data
daily_rfr = compute_daily_returns(rfr['risk_free_rate'])
market_excess_returns = compute_excess_returns(sp500['sp_500'], rfr['risk_free_rate'])
stock_excess_returns = stock_returns - daily_rfr

# %%
# Create the regression dataframe
regression_df = pd.DataFrame(index = stock_excess_returns.index)

regression_df['stock'] = stock_excess_returns
regression_df['MKT'] = market_excess_returns
regression_df['SMB'] = SMB
regression_df['HML'] = HML
regression_df.dropna(inplace = True)

regression_df
# Out:
#                stock       MKT       SMB       HML
# Date
# 2015-01-05 -0.009359 -0.018334  0.000614 -0.007472
# 2015-01-06 -0.014625 -0.008948 -0.002716 -0.000653
# 2015-01-07  0.012651  0.011576  0.000453 -0.003583
# 2015-01-08  0.029362  0.017832  0.002447 -0.002477
# 2015-01-09 -0.008460 -0.008458  0.001843 -0.001128
# ...              ...       ...       ...       ...
# 2024-10-22  0.020732 -0.000589 -0.005932  0.004081
# 2024-10-23 -0.006922 -0.009307  0.000967  0.005278
# 2024-10-24  0.000192  0.002031  0.003483 -0.006245
# 2024-10-25  0.007937 -0.000415 -0.000201 -0.004926
# 2024-10-28 -0.003760  0.002535  0.003316  0.006590
#
# [2454 rows x 4 columns]

# %%
# Create the Y Vector
y = regression_df['stock']

# Create the X Matrix
x = regression_df[['MKT', 'SMB', 'HML']]

# %%
x.corr()
# Out:
#           MKT       SMB       HML
# MKT  1.000000  0.242885  0.054839
# SMB  0.242885  1.000000  0.329923
# HML  0.054839  0.329923  1.000000

# %%
# Calculate Weights
window = len(y)

# The results of the model
results = capm_regression(
    y,
    x,
    window,
    True
)
    
#here we check the summary
print(results.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  stock   R-squared:                       0.723
# Model:                            WLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     2130.
# Date:                Mon, 21 Apr 2025   Prob (F-statistic):               0.00
# Time:                        19:19:56   Log-Likelihood:                 7962.4
# No. Observations:                2454   AIC:                        -1.592e+04
# Df Residuals:                    2450   BIC:                        -1.589e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.451e-05      0.000     -0.188      0.851      -0.000       0.000
# MKT            1.2511      0.017     75.434      0.000       1.219       1.284
# SMB           -0.4621      0.059     -7.826      0.000      -0.578      -0.346
# HML           -0.5648      0.026    -21.619      0.000      -0.616      -0.514
# ==============================================================================
# Omnibus:                      688.925   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20550.694
# Skew:                           0.695   Prob(JB):                         0.00
# Kurtosis:                      17.109   Cond. No.                         327.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Let us Create a new function
def FamaFrenchFactors(
    stock_returns: pd.Series, 
    market_returns: pd.Series, 
    small_minus_big_series: pd.Series,
    high_minus_low_series: pd.Series,
):

    # Align time series to the same date range
    common_index = stock_returns.index.intersection(market_returns.index) \
    .intersection(small_minus_big_series.index) \
    .intersection(high_minus_low_series.index)
    
    stock_returns = stock_returns.loc[common_index]
    market_returns = market_returns.loc[common_index]
    small_minus_big_series = small_minus_big_series.loc[common_index]
    high_minus_low_series = high_minus_low_series.loc[common_index]
    
    X = pd.concat([market_returns, small_minus_big_series, high_minus_low_series], axis=1)
    y = stock_returns

    # Create weights with exponential decay
    T = len(y)
    weights = T * wexp(T, T/2)
    
    # Fit WLS regression
    model = sm.WLS(y, sm.add_constant(X), weights=weights, missing='drop').fit()

    # Avoid KeyError by checking if params exist
    params = model.params
    
    alpha = params.iloc[0]
    capm_beta = params.iloc[1]
    smb_beta = params.iloc[2]
    hml_beta = params.iloc[3]
            
    parameters = {
        'alpha':alpha,
        'capm_beta':capm_beta,
        'smb_beta':smb_beta,
        'hml_beta':hml_beta,
    }
    
    return parameters

# %%
# Check if the Function Works

parameters = FamaFrenchFactors(
    stock_excess_returns,
    market_excess_returns,
    SMB,
    HML,
)

parameters
# Out:
# {'alpha': -3.450960231743508e-05,
#  'capm_beta': 1.2511018266618037,
#  'smb_beta': -0.46214538350169354,
#  'hml_beta': -0.5648331763206494}

# %% [markdown]
# ### Obtaining the Coefficients for all the Stocks ###

# %%
# Dictionary to store the DataFrames
folder_path = r"..\stocks"

dataframes = import_stock_universe(
    folder_path,
    ['Adjusted_close', 'Company Market Cap', 'Price_to_Book_inverse'],
    ['adj_close', 'mkt_cap', 'btp'],
)
# Out:
# File loaded: A (2472 rows)
# File loaded: AAPL (2472 rows)
# File loaded: ABBV (2472 rows)
# File skipped (less than 2000 rows after cleaning): ABNB.csv
# File loaded: ABT (2472 rows)
# File loaded: ADBE (2472 rows)
# File loaded: ADI (2472 rows)
# File loaded: ADM (2472 rows)
# File loaded: ADP (2472 rows)
# File loaded: T (2472 rows)
# File loaded: TAP (2472 rows)
# File loaded: TDG (2472 rows)
# File loaded: TDY (2472 rows)
# File loaded: TECH (2472 rows)
# File loaded: TER (2472 rows)
# File loaded: TFC (2472 rows)
# File loaded: TFX (2472 rows)
# File loaded: TGT (2472 rows)
# File loaded: TJX (2472 rows)
# File loaded: TPL (2464 rows)
# File loaded: TPR (2472 rows)
# File loaded: TRMB (2472 rows)
# File loaded: TROW (2472 rows)
# File loaded: TRV (2472 rows)
# File loaded: TSCO (2472 rows)
# File loaded: TSLA (2472 rows)
# File loaded: TXN (2472 rows)
# File loaded: TXT (2472 rows)
# File loaded: TYL (2472 rows)
# File skipped (less than 2000 rows after cleaning): UBER.csv
# File loaded: UDR (2472 rows)
# File loaded: UHS (2472 rows)
# File loaded: ULTA (2472 rows)
# File loaded: UNH (2472 rows)
# File loaded: UNP (2472 rows)
# File loaded: UPS (2472 rows)
# File loaded: USB (2472 rows)
# File loaded: V (2472 rows)
# File skipped (less than 2000 rows after cleaning): VICI.csv
# File loaded: VLO (2472 rows)
# File skipped (less than 2000 rows after cleaning): VLTO.csv
# File loaded: VMC (2472 rows)
# File loaded: VRSK (2472 rows)
# File loaded: VRSN (2472 rows)
# File loaded: VRTX (2471 rows)
# File skipped (less than 2000 rows after cleaning): VST.csv
# File loaded: VTR (2472 rows)
# File loaded: VTRS (2472 rows)
# File loaded: VZ (2472 rows)
# File loaded: WAB (2472 rows)
# File loaded: WAT (2472 rows)
# File loaded: WBA (2472 rows)
# File loaded: WBD (2472 rows)
# File loaded: WDAY (2472 rows)
# File loaded: WDC (2472 rows)
# File loaded: WEC (2472 rows)
# File loaded: WELL (2472 rows)
# File loaded: WFC (2472 rows)
# File loaded: WM (2472 rows)
# File loaded: WMB (2472 rows)
# File loaded: WMT (2472 rows)
# File loaded: WRB (2472 rows)
# File loaded: WST (2472 rows)
# File loaded: WY (2472 rows)
# File loaded: WYNN (2472 rows)
# File loaded: XEL (2472 rows)
# File loaded: XOM (2472 rows)
# File loaded: XYL (2472 rows)
# File loaded: YUM (2472 rows)
# File loaded: ZBH (2472 rows)
# File loaded: ZBRA (2472 rows)
# File loaded: ZTS (2472 rows)

# %%
# Calculate the Coefficients
tickers = []
betas_capm = []
betas_smb = []
betas_hml = []

# Create the Loop
for ticker in dataframes.keys():
    stock_returns = dataframes[ticker]['adj_close'].pct_change(1).dropna()
    stock_excess_returns = stock_returns - daily_rfr

    # Calculations
    parameters = FamaFrenchFactors(
        stock_excess_returns,
        market_excess_returns,
        SMB,
        HML,
    )

    tickers.append(ticker)
    betas_capm.append(parameters['mkt_beta'])
    betas_smb.append(parameters['smb_beta'])
    betas_hml.append(parameters['hml_beta'])

    print(f'{ticker} is ready.')
# Out:
# A is ready.
# AAPL is ready.
# ABBV is ready.
# ABT is ready.
# ADBE is ready.
# ADI is ready.
# ADM is ready.
# ADP is ready.
# ADSK is ready.
# AEE is ready.
# AEP is ready.
# AES is ready.
# AFL is ready.
# AIG is ready.
# AIZ is ready.
# AJG is ready.
# AKAM is ready.
# ALB is ready.
# ALGN is ready.
# ALL is ready.
# AMAT is ready.
# AMD is ready.
# AME is ready.
# AMGN is ready.
# AMP is ready.
# AMT is ready.
# AMZN is ready.
# ANET is ready.
# ANSS is ready.
# AOS is ready.
# APA is ready.
# APD is ready.
# APH is ready.
# APO is ready.
# ARE is ready.
# AWK is ready.
# BALL is ready.
# BDX is ready.
# BK is ready.
# BKNG is ready.
# BLDR is ready.
# BMY is ready.
# BR is ready.
# BRO is ready.
# BSX is ready.
# BWA is ready.
# BX is ready.
# BXP is ready.
# C is ready.
# CAG is ready.
# CAH is ready.
# CBRE is ready.
# CCI is ready.
# CDNS is ready.
# CDW is ready.
# CE is ready.
# CF is ready.
# CFG is ready.
# CHD is ready.
# CHRW is ready.
# CHTR is ready.
# CI is ready.
# CINF is ready.
# CL is ready.
# CLX is ready.
# CMCSA is ready.
# CME is ready.
# CMG is ready.
# CMI is ready.
# CMS is ready.
# CNC is ready.
# CNP is ready.
# COF is ready.
# COO is ready.
# COP is ready.
# COR is ready.
# COST is ready.
# CPB is ready.
# CPRT is ready.
# CRL is ready.
# CRM is ready.
# CSCO is ready.
# CSGP is ready.
# CSX is ready.
# CTAS is ready.
# CTRA is ready.
# CTSH is ready.
# CVS is ready.
# CVX is ready.
# CZR is ready.
# D is ready.
# DAL is ready.
# DE is ready.
# DECK is ready.
# DFS is ready.
# DG is ready.
# DGX is ready.
# DHI is ready.
# DHR is ready.
# DIS is ready.
# DLR is ready.
# DLTR is ready.
# DOC is ready.
# DOV is ready.
# DPZ is ready.
# DRI is ready.
# DTE is ready.
# DUK is ready.
# DVA is ready.
# DVN is ready.
# DXCM is ready.
# EA is ready.
# EBAY is ready.
# ECL is ready.
# ED is ready.
# EFX is ready.
# ERIE is ready.
# EVRG is ready.
# EW is ready.
# EXC is ready.
# EXPD is ready.
# EXPE is ready.
# EXR is ready.
# F is ready.
# FANG is ready.
# FAST is ready.
# FCX is ready.
# FDS is ready.
# FDX is ready.
# FE is ready.
# FFIV is ready.
# FI is ready.
# FICO is ready.
# FIS is ready.
# FITB is ready.
# FMC is ready.
# FSLR is ready.
# FTNT is ready.
# FTV is ready.
# GD is ready.
# GDDY is ready.
# GE is ready.
# GEN is ready.
# GILD is ready.
# GIS is ready.
# GL is ready.
# GLW is ready.
# GM is ready.
# GNRC is ready.
# GOOG is ready.
# GPC is ready.
# GPN is ready.
# GS is ready.
# GWW is ready.
# HAL is ready.
# HAS is ready.
# HBAN is ready.
# HCA is ready.
# HD is ready.
# HES is ready.
# HIG is ready.
# HII is ready.
# HLT is ready.
# HOLX is ready.
# HON is ready.
# HPE is ready.
# HPQ is ready.
# HRL is ready.
# HSIC is ready.
# HST is ready.
# HSY is ready.
# HUBB is ready.
# HUM is ready.
# HWM is ready.
# IBM is ready.
# ICE is ready.
# IDXX is ready.
# IEX is ready.
# IFF is ready.
# INCY is ready.
# INTC is ready.
# INTU is ready.
# IP is ready.
# IPG is ready.
# IQV is ready.
# IRM is ready.
# ISRG is ready.
# IT is ready.
# ITW is ready.
# J is ready.
# JBHT is ready.
# JBL is ready.
# JKHY is ready.
# JNJ is ready.
# JNPR is ready.
# JPM is ready.
# K is ready.
# KDP is ready.
# KEY is ready.
# KHC is ready.
# KIM is ready.
# KKR is ready.
# KLAC is ready.
# KMB is ready.
# KMI is ready.
# KMX is ready.
# KO is ready.
# KR is ready.
# L is ready.
# LDOS is ready.
# LHX is ready.
# LII is ready.
# LKQ is ready.
# LLY is ready.
# LMT is ready.
# LNT is ready.
# LOW is ready.
# LUV is ready.
# LVS is ready.
# LYV is ready.
# MA is ready.
# MAA is ready.
# MAR is ready.
# MAS is ready.
# MCD is ready.
# MCHP is ready.
# MCK is ready.
# MCO is ready.
# MDLZ is ready.
# MET is ready.
# META is ready.
# MGM is ready.
# MHK is ready.
# MKC is ready.
# MKTX is ready.
# MLM is ready.
# MMC is ready.
# MMM is ready.
# MNST is ready.
# MO is ready.
# MOH is ready.
# MOS is ready.
# MPC is ready.
# MPWR is ready.
# MRK is ready.
# MS is ready.
# MSCI is ready.
# MSFT is ready.
# MSI is ready.
# MTB is ready.
# MTD is ready.
# MU is ready.
# NDAQ is ready.
# NDSN is ready.
# NEE is ready.
# NEM is ready.
# NFLX is ready.
# NI is ready.
# NKE is ready.
# NOC is ready.
# NOW is ready.
# NRG is ready.
# NSC is ready.
# NTAP is ready.
# NUE is ready.
# NVDA is ready.
# NVR is ready.
# NWS is ready.
# NWSA is ready.
# O is ready.
# ODFL is ready.
# OKE is ready.
# OMC is ready.
# ON is ready.
# ORCL is ready.
# ORLY is ready.
# OXY is ready.
# PANW is ready.
# PARA is ready.
# PAYC is ready.
# PAYX is ready.
# PCAR is ready.
# PCG is ready.
# PEG is ready.
# PEP is ready.
# PFE is ready.
# PFG is ready.
# PG is ready.
# PGR is ready.
# PH is ready.
# PHM is ready.
# PKG is ready.
# PLD is ready.
# PM is ready.
# PNC is ready.
# PNW is ready.
# PODD is ready.
# POOL is ready.
# PPG is ready.
# PPL is ready.
# PRU is ready.
# PSA is ready.
# PSX is ready.
# PTC is ready.
# PWR is ready.
# PYPL is ready.
# QCOM is ready.
# REG is ready.
# REGN is ready.
# RF is ready.
# RJF is ready.
# RL is ready.
# RMD is ready.
# ROK is ready.
# ROL is ready.
# ROP is ready.
# ROST is ready.
# RSG is ready.
# RTX is ready.
# RVTY is ready.
# SBAC is ready.
# SBUX is ready.
# SCHW is ready.
# SHW is ready.
# SJM is ready.
# SNA is ready.
# SO is ready.
# SPG is ready.
# SPGI is ready.
# SRE is ready.
# STLD is ready.
# STT is ready.
# STZ is ready.
# SWKS is ready.
# SYF is ready.
# SYK is ready.
# SYY is ready.
# T is ready.
# TAP is ready.
# TDG is ready.
# TDY is ready.
# TECH is ready.
# TER is ready.
# TFC is ready.
# TFX is ready.
# TGT is ready.
# TJX is ready.
# TPL is ready.
# TPR is ready.
# TRMB is ready.
# TROW is ready.
# TRV is ready.
# TSCO is ready.
# TSLA is ready.
# TXN is ready.
# TXT is ready.
# TYL is ready.
# UDR is ready.
# UHS is ready.
# ULTA is ready.
# UNH is ready.
# UNP is ready.
# UPS is ready.
# USB is ready.
# V is ready.
# VLO is ready.
# VMC is ready.
# VRSK is ready.
# VRSN is ready.
# VRTX is ready.
# VTR is ready.
# VTRS is ready.
# VZ is ready.
# WAB is ready.
# WAT is ready.
# WBA is ready.
# WBD is ready.
# WDAY is ready.
# WDC is ready.
# WEC is ready.
# WELL is ready.
# WFC is ready.
# WM is ready.
# WMB is ready.
# WMT is ready.
# WRB is ready.
# WST is ready.
# WY is ready.
# WYNN is ready.
# XEL is ready.
# XOM is ready.
# XYL is ready.
# YUM is ready.
# ZBH is ready.
# ZBRA is ready.
# ZTS is ready.

# %%
# Create the DataFrame

ff_betas_df = pd.DataFrame(
    {
        'mkt_beta': betas_capm,
        'smb_beta': betas_smb,
        'hml_beta': betas_hml
    }, index = tickers,
)

ff_betas_df
# Out:
#       mkt_beta  smb_beta  hml_beta
# A     0.964129  0.632947 -0.337700
# AAPL  1.217553 -0.148842 -0.462690
# ABBV  0.650040 -0.737129  0.196142
# ABT   0.829190 -0.392084 -0.168315
# ADBE  1.322051 -0.155488 -0.933449
# ...        ...       ...       ...
# XYL   1.014274  0.740232  0.132192
# YUM   0.722600  0.496276  0.049465
# ZBH   0.794678  0.814363  0.267882
# ZBRA  1.226296  1.766695 -0.387113
# ZTS   0.918427  0.220257 -0.386791
#
# [396 rows x 3 columns]

# %%
# Calculate Mean and Standard Deviation
mu = ff_betas_df['mkt_beta'].mean()
sigma = ff_betas_df['mkt_beta'].std()
median = ff_betas_df['mkt_beta'].median()

# Create Histogram
plt.figure(figsize=(10, 6))
plt.hist(ff_betas_df['mkt_beta'], bins=30, density=True, color='lightskyblue', alpha=0.5, edgecolor='black', label='CAPM Betas Distribution')

# Generate the Values of the Normal Distribution
x = np.linspace(ff_betas_df['mkt_beta'].min(), ff_betas_df['mkt_beta'].max(), 100)
y = norm.pdf(x, mu, sigma)

# Graph the Real Normal Distribution
plt.plot(x, y, color='black', linestyle='solid', linewidth=2, label='Normal Distribution')

# Reference Lines
plt.axvline(x=mu, color='black', linestyle='dashed', label='Mean Returns')
plt.axvline(x=median, color='red', linestyle='dashed', label='Median Returns')
plt.axvline(x=mu + sigma, color='grey', linestyle='dashed')
plt.axvline(x=mu - sigma, color='grey', linestyle='dashed')

# Config
plt.title('CAPM Betas Histogram with Normal Distribution')
plt.xlabel('Return')
plt.ylabel('Density')

# Legends and Grid
plt.legend()
plt.grid(True)

# Show
plt.show()

# %%
# Calculate Mean and Standard Deviation
mu = ff_betas_df['smb_beta'].mean()
sigma = ff_betas_df['smb_beta'].std()
median = ff_betas_df['smb_beta'].median()

# Create Histogram
plt.figure(figsize=(10, 6))
plt.hist(ff_betas_df['smb_beta'], bins=30, density=True, color='lightgreen', alpha=0.5, edgecolor='black', label='SMB Betas Distribution')

# Generate the Values of the Normal Distribution
x = np.linspace(ff_betas_df['smb_beta'].min(), ff_betas_df['smb_beta'].max(), 100)
y = norm.pdf(x, mu, sigma)

# Graph the Real Normal Distribution
plt.plot(x, y, color='black', linestyle='solid', linewidth=2, label='Normal Distribution')

# Reference Lines
plt.axvline(x=mu, color='black', linestyle='dashed', label='Mean Returns')
plt.axvline(x=median, color='red', linestyle='dashed', label='Median Returns')
plt.axvline(x=mu + sigma, color='grey', linestyle='dashed')
plt.axvline(x=mu - sigma, color='grey', linestyle='dashed')

# Config
plt.title('SMB Betas Histogram with Normal Distribution')
plt.xlabel('Return')
plt.ylabel('Density')

# Legends and Grid
plt.legend()
plt.grid(True)

# Show
plt.show()

# %%
# Calculate Mean and Standard Deviation
mu = ff_betas_df['hml_beta'].mean()
sigma = ff_betas_df['hml_beta'].std()
median = ff_betas_df['hml_beta'].median()

# Create Histogram
plt.figure(figsize=(10, 6))
plt.hist(ff_betas_df['hml_beta'], bins=30, density=True, color='salmon', alpha=0.5, edgecolor='black', label='HML Betas Distribution')

# Generate the Values of the Normal Distribution
x = np.linspace(ff_betas_df['hml_beta'].min(), ff_betas_df['hml_beta'].max(), 100)
y = norm.pdf(x, mu, sigma)

# Graph the Real Normal Distribution
plt.plot(x, y, color='black', linestyle='solid', linewidth=2, label='Normal Distribution')

# Reference Lines
plt.axvline(x=mu, color='black', linestyle='dashed', label='Mean Returns')
plt.axvline(x=median, color='red', linestyle='dashed', label='Median Returns')
plt.axvline(x=mu + sigma, color='grey', linestyle='dashed')
plt.axvline(x=mu - sigma, color='grey', linestyle='dashed')

# Config
plt.title('HML Betas Histogram with Normal Distribution')
plt.xlabel('Return')
plt.ylabel('Density')

# Legends and Grid
plt.legend()
plt.grid(True)

# Show
plt.show()

# %%
# Calculate the VIF
# Concat
X = pd.concat([
    market_excess_returns,
    SMB,
    HML,
], axis=1, join='inner')


X.dropna(inplace = True)

X.columns = ['mkt', 'smb', 'hml']

X
# Out:
#                  mkt       smb       hml
# Date
# 2015-01-05 -0.018334  0.000614 -0.007472
# 2015-01-06 -0.008948 -0.002716 -0.000653
# 2015-01-07  0.011576  0.000453 -0.003583
# 2015-01-08  0.017832  0.002447 -0.002477
# 2015-01-09 -0.008458  0.001843 -0.001128
# ...              ...       ...       ...
# 2024-10-22 -0.000589 -0.005932  0.004081
# 2024-10-23 -0.009307  0.000967  0.005278
# 2024-10-24  0.002031  0.003483 -0.006245
# 2024-10-25 -0.000415 -0.000201 -0.004926
# 2024-10-28  0.002535  0.003316  0.006590
#
# [2454 rows x 3 columns]

# %%
vif_data = pd.DataFrame()
vif_data['vars'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

vif_data
# Out:
#   vars       VIF
# 0  mkt  1.063432
# 1  smb  1.189769
# 2  hml  1.122839

# %%
r_squared_df = pd.DataFrame()
r_squared_df['vars'] = X.columns

r_squared_df['r_squared'] = 1 - (1 / vif_data['VIF'])

r_squared_df
# Out:
#   vars  r_squared
# 0  mkt   0.059648
# 1  smb   0.159501
# 2  hml   0.109400

# %%
ff_betas_df.to_csv(r"..\additional_data\famafrench_betas.csv")
